# %% [markdown]
# # ib_insync
#
# Built on top of the native Python API from Interactive Brokers
#
# Do check out the documentation for all the benefits of using the library
#
# # Preamble
#
# 1. You will need to have TWS station running or IB Gateway running
# 2. Python version 3.6 or higher
# 3. Interactive Brokers Python API version 9.73 or higher
# 4. Ensure your API port is enabled. I use port 4002. Default is 9497.

# %%
# !pip3 install -U ib_insync
# Out:
# /bin/sh: 1: pip3: not found

# %% [markdown]
# # Github:
# https://github.com/erdewit/ib_insync
#
# # Documentation:
# https://rawgit.com/erdewit/ib_insync/master/docs/html/readme.html

# %% [markdown]
# ***

# %% [markdown]
# # Connection

# %%
from ib_insync import *

# %%
ib = IB()
ib.connect('127.0.0.1', 7497, clientId=101)
# Out:
# ERROR:ib_insync.client:Peer closed connection
# ERROR:ib_insync.client:clientId 101 already in use?
# ERROR:ib_insync.client:API connection failed: TimeoutError()
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# <ipython-input-61-2ebd1b0e3923> in <module>()
#       1 ib = IB()
# ----> 2 ib.connect('127.0.0.1', 7497, clientId=101)
#
# /usr/local/anaconda3/lib/python3.6/site-packages/ib_insync/ib.py in connect(self, host, port, clientId, timeout)
#     199         This method is blocking.
#     200         """
# --> 201         self.run(self.connectAsync(host, port, clientId, timeout))
#     202         return self
#     203
#
# /usr/local/anaconda3/lib/python3.6/site-packages/ib_insync/ib.py in run(*awaitables)
#     248             else:
#     249                 future = asyncio.gather(*awaitables)
# --> 250             result = util.syncAwait(future)
#     251         return result
#     252
#
# /usr/local/anaconda3/lib/python3.6/site-packages/ib_insync/util.py in syncAwait(future)
#     239
#     240     if not loop.is_running():
# --> 241         result = loop.run_until_complete(future)
#     242     elif isQuamash:
#     243         result = _syncAwaitQt(future)
#
# /usr/local/anaconda3/lib/python3.6/asyncio/base_events.py in run_until_complete(self, future)
#     465             raise RuntimeError('Event loop stopped before Future completed.')
#     466
# --> 467         return future.result()
#     468
#     469     def stop(self):
#
# /usr/local/anaconda3/lib/python3.6/site-packages/ib_insync/ib.py in connectAsync(self, host, port, clientId, timeout)
#    1225     async def connectAsync(self, host, port, clientId, timeout=2):
#    1226         self.wrapper.clientId = clientId
# -> 1227         await self.client.connectAsync(host, port, clientId, timeout)
#    1228         accounts = self.client.getAccounts()
#    1229         await asyncio.gather(
#
# /usr/local/anaconda3/lib/python3.6/site-packages/ib_insync/client.py in connectAsync(self, host, port, clientId, timeout)
#     161         try:
#     162             await asyncio.wait_for(asyncio.gather(
# --> 163                     self.conn.connect(), self._readyEvent.wait()), timeout)
#     164             self._logger.info('API connection ready')
#     165             self.apiStart()
#
# /usr/local/anaconda3/lib/python3.6/asyncio/tasks.py in wait_for(fut, timeout, loop)
#     360             fut.remove_done_callback(cb)
#     361             fut.cancel()
# --> 362             raise futures.TimeoutError()
#     363     finally:
#     364         timeout_handle.cancel()
#
# TimeoutError:

# %% [markdown]
# ***

# %% [markdown]
# # Download Historical Data
#
# http://interactivebrokers.github.io/tws-api/historical_bars.html

# %% [markdown]
# ## Forex

# %%
contract = Forex('EURUSD')
# contract = Future('HSI', '20180628', 'HKFE')
bars = ib.reqHistoricalData(contract, 
                            endDateTime='20180430 09:00:00', 
                            durationStr='20 D',
                            barSizeSetting='30 secs', 
                            whatToShow='MIDPOINT', 
                            useRTH=True)

# %%
bars[:10]
# Out:
# [BarData(date=datetime.datetime(2018, 4, 3, 5, 15), open=1.230425, high=1.23049, low=1.230285, close=1.23035, volume=-1, barCount=-1, average=-1.0),
#  BarData(date=datetime.datetime(2018, 4, 3, 5, 15, 30), open=1.23035, high=1.23035, low=1.23034, close=1.23035, volume=-1, barCount=-1, average=-1.0),
#  BarData(date=datetime.datetime(2018, 4, 3, 5, 16), open=1.23035, high=1.230365, low=1.23033, close=1.23034, volume=-1, barCount=-1, average=-1.0),
#  BarData(date=datetime.datetime(2018, 4, 3, 5, 16, 30), open=1.23034, high=1.23035, low=1.23034, close=1.23034, volume=-1, barCount=-1, average=-1.0),
#  BarData(date=datetime.datetime(2018, 4, 3, 5, 17), open=1.23034, high=1.23034, low=1.23034, close=1.23034, volume=-1, barCount=-1, average=-1.0),
#  BarData(date=datetime.datetime(2018, 4, 3, 5, 17, 30), open=1.23034, high=1.23037, low=1.23034, close=1.23034, volume=-1, barCount=-1, average=-1.0),
#  BarData(date=datetime.datetime(2018, 4, 3, 5, 18), open=1.23034, high=1.23034, low=1.23034, close=1.23034, volume=-1, barCount=-1, average=-1.0),
#  BarData(date=datetime.datetime(2018, 4, 3, 5, 18, 30), open=1.23034, high=1.23034, low=1.23034, close=1.23034, volume=-1, barCount=-1, average=-1.0),
#  BarData(date=datetime.datetime(2018, 4, 3, 5, 19), open=1.23034, high=1.23035, low=1.23034, close=1.23034, volume=-1, barCount=-1, average=-1.0),
#  BarData(date=datetime.datetime(2018, 4, 3, 5, 19, 30), open=1.23034, high=1.23037, low=1.23032, close=1.23036, volume=-1, barCount=-1, average=-1.0)]

# %% [markdown]
# We make use of the `util` library that comes with ib_insync to render the diplay in a more human readable format.
# https://rawgit.com/erdewit/ib_insync/master/docs/html/api.html#module-ib_insync.util

# %%
df = util.df(bars)
df[['date', 'open', 'high', 'low', 'close']].head()
# Out:
#                  date      open      high       low    close
# 0 2018-04-03 05:15:00  1.230425  1.230490  1.230285  1.23035
# 1 2018-04-03 05:15:30  1.230350  1.230350  1.230340  1.23035
# 2 2018-04-03 05:16:00  1.230350  1.230365  1.230330  1.23034
# 3 2018-04-03 05:16:30  1.230340  1.230350  1.230340  1.23034
# 4 2018-04-03 05:17:00  1.230340  1.230340  1.230340  1.23034

# %%
df.to_csv('test.csv')

# %%
len(df)
# Out:
# 450

# %%
# %matplotlib inline
df.close.plot()

# %%
contract = Future('HSI', '20180628', 'HKFE')
bars = ib.reqHistoricalData(contract, 
                            endDateTime='', 
                            durationStr='1 D',
                            barSizeSetting='30 secs', 
                            whatToShow='MIDPOINT', 
                            useRTH=True)

# %%
bars[:10]
# Out:
# [BarData(date=datetime.datetime(2018, 5, 15, 9, 15), open=31332.5, high=31334.0, low=31261.0, close=31270.0, volume=-1, barCount=-1, average=-1.0),
#  BarData(date=datetime.datetime(2018, 5, 15, 9, 15, 30), open=31270.0, high=31272.5, low=31256.0, close=31269.5, volume=-1, barCount=-1, average=-1.0),
#  BarData(date=datetime.datetime(2018, 5, 15, 9, 16), open=31269.5, high=31279.5, low=31262.0, close=31264.5, volume=-1, barCount=-1, average=-1.0),
#  BarData(date=datetime.datetime(2018, 5, 15, 9, 16, 30), open=31264.5, high=31264.5, low=31247.5, close=31254.5, volume=-1, barCount=-1, average=-1.0),
#  BarData(date=datetime.datetime(2018, 5, 15, 9, 17), open=31254.5, high=31268.0, low=31247.0, close=31266.5, volume=-1, barCount=-1, average=-1.0),
#  BarData(date=datetime.datetime(2018, 5, 15, 9, 17, 30), open=31266.5, high=31278.0, low=31264.5, close=31278.0, volume=-1, barCount=-1, average=-1.0),
#  BarData(date=datetime.datetime(2018, 5, 15, 9, 18), open=31278.0, high=31278.0, low=31262.0, close=31266.0, volume=-1, barCount=-1, average=-1.0),
#  BarData(date=datetime.datetime(2018, 5, 15, 9, 18, 30), open=31266.0, high=31268.0, low=31254.5, close=31261.0, volume=-1, barCount=-1, average=-1.0),
#  BarData(date=datetime.datetime(2018, 5, 15, 9, 19), open=31261.0, high=31268.5, low=31251.5, close=31263.5, volume=-1, barCount=-1, average=-1.0),
#  BarData(date=datetime.datetime(2018, 5, 15, 9, 19, 30), open=31263.5, high=31269.5, low=31261.5, close=31269.0, volume=-1, barCount=-1, average=-1.0)]

# %% [markdown]
# ***

# %% [markdown]
# # Account and Portfolio
# # Account Values
#
# To extract main account details only
#
# http://interactivebrokers.github.io/tws-api/account_updates.html
#
# This is the `updateAccountValue` in the documentation http://interactivebrokers.github.io/tws-api/interfaceIBApi_1_1EWrapper.html#ae15a34084d9f26f279abd0bdeab1b9b5

# %%
util.df(ib.accountValues())

# %%
[v for v in ib.accountValues() if v.tag=="NetLiquidation"]
# Out:
# [AccountValue(account='DI246990', tag='NetLiquidation', value='1194091.10', currency='USD', modelCode='')]

# %% [markdown]
# # Portfolio
#
# http://interactivebrokers.github.io/tws-api/account_updates.html

# %%
ib.portfolio()[0]
# Out:
# PortfolioItem(contract=Contract(secType='STK', conId=265598, symbol='AAPL', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='AAPL', tradingClass='NMS'), position=200.0, marketPrice=175.3860016, marketValue=35077.2, averageCost=174.95, unrealizedPNL=87.2, realizedPNL=0.0, account='DI246990')

# %%
util.df(ib.portfolio())
# Out:
#                                             contract  position  marketPrice  \
# 0  Contract(secType='STK', conId=265598, symbol='...     200.0   175.386002
# 1  Contract(secType='OPT', conId=197397509, symbo...       2.0     0.000753
# 2  Contract(secType='OPT', conId=197397584, symbo...      -2.0     6.363560
# 3  Contract(secType='FUT', conId=269745169, symbo...       2.0  2673.750000
# 4  Contract(secType='FUT', conId=279396694, symbo...      22.0  2678.300049
# 5  Contract(secType='CASH', conId=12087792, symbo...  150000.0     1.236770
# 6  Contract(secType='STK', conId=208813720, symbo...     600.0  1033.466309
# 7  Contract(secType='STK', conId=43645865, symbol...       7.0    71.591064
# 8  Contract(secType='STK', conId=9408, symbol='MC...      -4.0   161.873093
# 9  Contract(secType='CASH', conId=15016059, symbo...  300000.0   107.261505
#
#    marketValue    averageCost  unrealizedPNL  realizedPNL   account
# 0     35077.20     174.950000          87.20          0.0  DI246990
# 1         0.17     244.600000        -489.03          0.0  DI246990
# 2     -1426.00     432.400000        -561.20          0.0  DI246990
# 3    267375.00  132852.050000        1670.90          0.0  DI246990
# 4   2946130.05  132968.527273       20822.45          0.0  DI246990
# 5    185515.51       1.122282       17173.14          0.0  DI246990
# 6    620079.79    1005.994583       16483.04          0.0  DI246990
# 7       501.14      38.837800         229.27          0.0  DI246990
# 8      -647.49     121.264725        -162.43          0.0  DI246990
# 9  32178451.54     107.258481         907.38          0.0  DI246990

# %% [markdown]
# # Account Summary
#
# To extract all accounts including managed accounts
#
# http://interactivebrokers.github.io/tws-api/account_summary.html

# %%
util.df(ib.accountSummary())
# Out:
#       account                       tag       value currency modelCode
# 0    DI246990               AccountType  INDIVIDUAL
# 1    DI246990                   Cushion     0.78756
# 2    DI246990        DayTradesRemaining          -1
# 3    DI246990       LookAheadNextChange  1523908800
# 4    DI246990               AccruedCash      183.61      USD
# 5    DI246990            AvailableFunds   920438.44      USD
# 6    DI246990               BuyingPower  3761673.77      USD
# 7    DI246990       EquityWithLoanValue  1114171.10      USD
# 8    DI246990           ExcessLiquidity   940418.44      USD
# 9    DI246990        FullAvailableFunds   820538.44      USD
# 10   DI246990       FullExcessLiquidity   860498.44      USD
# 11   DI246990         FullInitMarginReq   373552.66      USD
# 12   DI246990        FullMaintMarginReq   333592.66      USD
# 13   DI246990        GrossPositionValue   658069.45      USD
# 14   DI246990             InitMarginReq   273652.66      USD
# 15   DI246990   LookAheadAvailableFunds   820538.44      USD
# 16   DI246990  LookAheadExcessLiquidity   860498.44      USD
# 17   DI246990    LookAheadInitMarginReq   373552.66      USD
# 18   DI246990   LookAheadMaintMarginReq   333592.66      USD
# 19   DI246990            MaintMarginReq   253672.66      USD
# 20   DI246990            NetLiquidation  1194091.10      USD
# 21   DI246990                       SMA   604553.14      USD
# 22   DI246990            TotalCashValue   540660.28      USD
# 23   DU274370               AccountType  INDIVIDUAL
# 24   DU274370                   Cushion    0.815806
# 25   DU274370        DayTradesRemaining          -1
# 26   DU274370       LookAheadNextChange           0
# 27   DU274370               AccruedCash     -938.41      USD
# 28   DU274370            AvailableFunds  1279374.58      USD
# 29   DU274370               BuyingPower  5117498.32      USD
# ..        ...                       ...         ...      ...       ...
# 867  DU973432  LookAheadExcessLiquidity   932747.67      USD
# 868  DU973432    LookAheadInitMarginReq    56836.05      USD
# 869  DU973432   LookAheadMaintMarginReq    56836.05      USD
# 870  DU973432            MaintMarginReq    56836.05      USD
# 871  DU973432            NetLiquidation   989583.72      USD
# 872  DU973432                       SMA   876085.02      USD
# 873  DU973432            TotalCashValue   761971.88      USD
# 874  DU981355               AccountType  INDIVIDUAL
# 875  DU981355                   Cushion           1
# 876  DU981355        DayTradesRemaining          -1
# 877  DU981355       LookAheadNextChange           0
# 878  DU981355               AccruedCash      392.49      USD
# 879  DU981355            AvailableFunds  1001476.79      USD
# 880  DU981355               BuyingPower  4005907.16      USD
# 881  DU981355       EquityWithLoanValue  1001476.79      USD
# 882  DU981355           ExcessLiquidity  1001476.79      USD
# 883  DU981355        FullAvailableFunds  1001476.79      USD
# 884  DU981355       FullExcessLiquidity  1001476.79      USD
# 885  DU981355         FullInitMarginReq        0.00      USD
# 886  DU981355        FullMaintMarginReq        0.00      USD
# 887  DU981355        GrossPositionValue        0.00      USD
# 888  DU981355             InitMarginReq        0.00      USD
# 889  DU981355   LookAheadAvailableFunds  1001476.79      USD
# 890  DU981355  LookAheadExcessLiquidity  1001476.79      USD
# 891  DU981355    LookAheadInitMarginReq        0.00      USD
# 892  DU981355   LookAheadMaintMarginReq        0.00      USD
# 893  DU981355            MaintMarginReq        0.00      USD
# 894  DU981355            NetLiquidation  1001476.79      USD
# 895  DU981355                       SMA  1001476.79      USD
# 896  DU981355            TotalCashValue  1001084.30      USD
#
# [897 rows x 5 columns]

# %% [markdown]
# ***

# %% [markdown]
# # Contracts

# %% [markdown]
# ib_insync has written a nice wrapper and added functionalities to define contracts easily.
#
# https://rawgit.com/erdewit/ib_insync/master/docs/html/api.html#module-ib_insync.contract

# %% [markdown]
# ## Stocks

# %%
contract = Stock('IBM', 'SMART', 'USD')

# %%
ib.reqContractDetails(contract)
# Out:
# [ContractDetails(summary=Contract(secType='STK', conId=8314, symbol='IBM', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='IBM', tradingClass='IBM'), marketName='IBM', minTick=0.01, orderTypes='ACTIVETIM,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DARKONLY,DARKPOLL,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,GAT,GTC,GTD,GTT,HID,IBKRATS,ICE,IMB,IOC,LIT,LMT,LOC,MIT,MKT,MOC,MTL,NGCOMB,NODARK,NONALGO,OCA,OPG,OPGREROUT,PEGBENCH,POSTONLY,PREOPGRTH,REL,RPI,RTH,RTHIGNOPG,SCALE,SCALEODD,SCALERST,SNAPMID,SNAPMKT,SNAPREL,SOLICITED,STP,STPLMT,SWEEP,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='SMART,AMEX,NYSE,CBOE,ISE,CHX,ARCA,ISLAND,VWAP,DRCTEDGE,NSX,BEX,BATS,EDGEA,CSFBALGO,JEFFALGO,BYX,IEX,TPLUS1,PSX', priceMagnifier=1, longName='INTL BUSINESS MACHINES CORP', industry='Technology', category='Computers', subcategory='Computer Services', timeZoneId='EST', tradingHours='20180416:0400-2000;20180417:0400-2000', liquidHours='20180416:0930-1600;20180417:0930-1600', mdSizeMultiplier=100)]

# %% [markdown]
# ## Futures

# %%
contract = Future('ES', '20181221', 'GLOBEX')
ib.reqContractDetails(contract)
# Out:
# [ContractDetails(summary=Contract(secType='FUT', conId=289128563, symbol='ES', lastTradeDateOrContractMonth='20181221', multiplier='50', exchange='GLOBEX', currency='USD', localSymbol='ESZ8', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='ACTIVETIM,ADJUST,ALERT,ALGO,ALLOC,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,LTH,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,PEGBENCH,SCALE,SCALERST,SNAPMID,SNAPMKT,SNAPREL,SOLICITED,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='GLOBEX', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='201812', timeZoneId='America/Belize', tradingHours='20180416:1700-1515,1530-1600;20180417:1700-1515,1530-1600', liquidHours='20180416:0830-1515,1530-1600;20180417:0830-1515,1530-1600', mdSizeMultiplier=1)]

# %%
contract = Future(localSymbol='ESZ7', includeExpired=True)
ib.reqContractDetails(contract)
# Out:
# [ContractDetails(summary=Contract(secType='FUT', conId=247950613, symbol='ES', lastTradeDateOrContractMonth='20171215', multiplier='50', exchange='GLOBEX', currency='USD', localSymbol='ESZ7', tradingClass='ES'), marketName='ES', minTick=0.25, orderTypes='LTH', validExchanges='GLOBEX', priceMagnifier=1, underConId=11004968, longName='E-mini S&P 500', contractMonth='201712', mdSizeMultiplier=1)]

# %% [markdown]
# ## Forex

# %%
contract = Forex('USDJPY')
ib.reqContractDetails(contract)
# Out:
# [ContractDetails(summary=Contract(secType='CASH', conId=15016059, symbol='USD', exchange='IDEALPRO', currency='JPY', localSymbol='USD.JPY', tradingClass='USD.JPY'), marketName='USD.JPY', minTick=0.005, orderTypes='ACTIVETIM,ADJUST,ALERT,ALGO,ALLOC,AVGCOST,BASKET,CASHQTY,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,IOC,LIT,LMT,MIT,MKT,NONALGO,OCA,REL,SCALE,SCALERST,SOLICITED,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='IDEALPRO', priceMagnifier=1, longName='United States dollar', timeZoneId='EST', tradingHours='20180416:1715-1700;20180417:1715-1700', liquidHours='20180416:1715-1700;20180417:1715-1700', mdSizeMultiplier=1)]

# %% [markdown]
# If you know the conId of the asset, you can directly specify it as well

# %%
contract = Contract(conId=15016059)
ib.reqContractDetails(contract)
# Out:
# [ContractDetails(summary=Contract(secType='CASH', conId=15016059, symbol='USD', exchange='IDEALPRO', currency='JPY', localSymbol='USD.JPY', tradingClass='USD.JPY'), marketName='USD.JPY', minTick=0.005, orderTypes='ACTIVETIM,ADJUST,ALERT,ALGO,ALLOC,AVGCOST,BASKET,CASHQTY,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,GAT,GTC,GTD,GTT,HID,IOC,LIT,LMT,MIT,MKT,NONALGO,OCA,REL,SCALE,SCALERST,SOLICITED,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,WHATIF', validExchanges='IDEALPRO', priceMagnifier=1, longName='United States dollar', timeZoneId='EST', tradingHours='20180416:1715-1700;20180417:1715-1700', liquidHours='20180416:1715-1700;20180417:1715-1700', mdSizeMultiplier=1)]

# %% [markdown]
# ## Options

# %%
contract = Option('NFLX', '20190621', 300, 'C', 'SMART')
ib.reqContractDetails(contract)
# Out:
# [ContractDetails(summary=Contract(secType='OPT', conId=292902077, symbol='NFLX', lastTradeDateOrContractMonth='20190621', strike=300.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='NFLX  190621C00300000', tradingClass='NFLX'), marketName='NFLX', minTick=0.01, orderTypes='ACTIVETIM,ADJUST,ALERT,ALGO,ALLOC,AON,AVGCOST,BASKET,COND,CONDORDER,DAY,DEACT,DEACTDIS,DEACTEOD,DIS,FOK,GAT,GTC,GTD,GTT,HID,ICE,IOC,LIT,LMT,MIT,MKT,MTL,NGCOMB,NONALGO,OCA,PAON,PEGMIDVOL,PEGMKTVOL,PEGPRMVOL,PEGSRFVOL,POSTONLY,REL,RELSTK,SCALE,SCALERST,SMARTSTG,SNAPMID,SNAPMKT,SNAPREL,SOLICITED,STP,STPLMT,TRAIL,TRAILLIT,TRAILLMT,TRAILMIT,VOLAT,WHATIF', validExchanges='SMART,AMEX,CBOE,PHLX,PSE,ISE,BOX,BATS,NASDAQOM,CBOE2,NASDAQBX,MIAX,GEMINI,EDGX,MERCURY,PEARL', priceMagnifier=1, underConId=15124833, longName='NETFLIX INC', contractMonth='201906', industry='Communications', category='Internet', subcategory='Internet Content-Entmnt', timeZoneId='EST', tradingHours='20180416:0930-1600;20180417:0930-1600', liquidHours='20180416:0930-1600;20180417:0930-1600', mdSizeMultiplier=1)]

# %%
contract = Future('ES')
cnt = ib.reqContractDetails(contract)
len(cnt)
# Out:
# 19

# %%
dat = [res.summary for res in cnt]
util.df(dat)
# Out:
#    secType      conId symbol lastTradeDateOrContractMonth  strike right  \
# 0      FUT  269745169     ES                     20180615     0.0
# 1      FUT  279396694     ES                     20180921     0.0
# 2      FUT  289128563     ES                     20181221     0.0
# 3      FUT  293147218     ES                     20180615     0.0
# 4      FUT  299552802     ES                     20190315     0.0
# 5      FUT  303443823     ES                     20180921     0.0
# 6      FUT  307369601     ES                     20180420     0.0
# 7      FUT  310629209     ES                     20190621     0.0
# 8      FUT  310868937     ES                     20180518     0.0
# 9      FUT  312047529     ES                     20180427     0.0
# 10     FUT  312864622     ES                     20180504     0.0
# 11     FUT  313497184     ES                     20180511     0.0
# 12     FUT  313497189     ES                     20180416     0.0
# 13     FUT  313747377     ES                     20180417     0.0
# 14     FUT  313817034     ES                     20180418     0.0
# 15     FUT  313867068     ES                     20180419     0.0
# 16     FUT  314196637     ES                     20180420     0.0
# 17     FUT  314280302     ES                     20180525     0.0
# 18     FUT  314280304     ES                     20180423     0.0
#
#    multiplier exchange primaryExchange currency localSymbol tradingClass  \
# 0          50   GLOBEX                      USD        ESM8           ES
# 1          50   GLOBEX                      USD        ESU8           ES
# 2          50   GLOBEX                      USD        ESZ8           ES
# 3         100      ONE                      USD      ES1DM8         ES1D
# 4          50   GLOBEX                      USD        ESH9           ES
# 5         100      ONE                      USD      ES1DU8         ES1D
# 6         100      ONE                      USD      ES1DJ8         ES1D
# 7          50   GLOBEX                      USD        ESM9           ES
# 8         100      ONE                      USD      ES1DK8         ES1D
# 9         100      ONE                      USD      ES1KJ8         ES1K
# 10        100      ONE                      USD      ES1IK8         ES1I
# 11        100      ONE                      USD      ES1JK8         ES1J
# 12        100      ONE                      USD      ES3MJ8         ES3M
# 13        100      ONE                      USD      ES3TJ8         ES3T
# 14        100      ONE                      USD      ES3WJ8         ES3W
# 15        100      ONE                      USD      ES3HJ8         ES3H
# 16        100      ONE                      USD      ES3FJ8         ES3F
# 17        100      ONE                      USD      ES1KK8         ES1K
# 18        100      ONE                      USD      ES4MJ8         ES4M
#
#     includeExpired secIdType secId comboLegsDescrip comboLegs underComp
# 0            False                                       None      None
# 1            False                                       None      None
# 2            False                                       None      None
# 3            False                                       None      None
# 4            False                                       None      None
# 5            False                                       None      None
# 6            False                                       None      None
# 7            False                                       None      None
# 8            False                                       None      None
# 9            False                                       None      None
# 10           False                                       None      None
# 11           False                                       None      None
# 12           False                                       None      None
# 13           False                                       None      None
# 14           False                                       None      None
# 15           False                                       None      None
# 16           False                                       None      None
# 17           False                                       None      None
# 18           False                                       None      None

# %%
contract = Stock('IBM')
cnt = ib.reqContractDetails(contract)
len(cnt)
# Out:
# 25

# %%
dat = [res.summary for res in cnt]
dat[0]
# Out:
# Contract(secType='STK', conId=8314, symbol='IBM', exchange='AMEX', primaryExchange='NYSE', currency='USD', localSymbol='IBM', tradingClass='IBM')

# %%
util.df(dat)
# Out:
#    secType     conId symbol lastTradeDateOrContractMonth  strike right  \
# 0      STK      8314    IBM                                  0.0
# 1      STK      8314    IBM                                  0.0
# 2      STK      8314    IBM                                  0.0
# 3      STK      8314    IBM                                  0.0
# 4      STK      8314    IBM                                  0.0
# 5      STK      8314    IBM                                  0.0
# 6      STK      8314    IBM                                  0.0
# 7      STK      8314    IBM                                  0.0
# 8      STK      8314    IBM                                  0.0
# 9      STK      8314    IBM                                  0.0
# 10     STK      8314    IBM                                  0.0
# 11     STK      8314    IBM                                  0.0
# 12     STK      8314    IBM                                  0.0
# 13     STK      8314    IBM                                  0.0
# 14     STK      8314    IBM                                  0.0
# 15     STK      8314    IBM                                  0.0
# 16     STK      8314    IBM                                  0.0
# 17     STK      8314    IBM                                  0.0
# 18     STK   1411277    IBM                                  0.0
# 19     STK   1411277    IBM                                  0.0
# 20     STK   1411277    IBM                                  0.0
# 21     STK   1411277    IBM                                  0.0
# 22     STK  38709473    IBM                                  0.0
# 23     STK      8314    IBM                                  0.0
# 24     STK   1411277    IBM                                  0.0
#
#    multiplier  exchange primaryExchange currency localSymbol tradingClass  \
# 0                  AMEX            NYSE      USD         IBM          IBM
# 1                  NYSE            NYSE      USD         IBM          IBM
# 2                  CBOE            NYSE      USD         IBM          IBM
# 3                   ISE            NYSE      USD         IBM          IBM
# 4                   CHX            NYSE      USD         IBM          IBM
# 5                  ARCA            NYSE      USD         IBM          IBM
# 6                ISLAND            NYSE      USD         IBM          IBM
# 7              DRCTEDGE            NYSE      USD         IBM          IBM
# 8                   NSX            NYSE      USD         IBM          IBM
# 9                   BEX            NYSE      USD         IBM          IBM
# 10                 BATS            NYSE      USD         IBM          IBM
# 11                EDGEA            NYSE      USD         IBM          IBM
# 12             CSFBALGO            NYSE      USD         IBM          IBM
# 13             JEFFALGO            NYSE      USD         IBM          IBM
# 14                  BYX            NYSE      USD         IBM          IBM
# 15                  IEX            NYSE      USD         IBM          IBM
# 16             CVGXALGO            NYSE      USD         IBM          IBM
# 17                  PSX            NYSE      USD         IBM          IBM
# 18                  FWB             FWB      EUR         IBM      USSTARS
# 19                 IBIS             FWB      EUR         IBM      USSTARS
# 20                  SWB             FWB      EUR         IBM        XETRA
# 21                TGATE             FWB      EUR         IBM          IBM
# 22                 MEXI            MEXI      MXN         IBM          IBM
# 23                SMART            NYSE      USD         IBM          IBM
# 24                SMART             FWB      EUR         IBM      USSTARS
#
#     includeExpired secIdType secId comboLegsDescrip comboLegs underComp
# 0            False                                       None      None
# 1            False                                       None      None
# 2            False                                       None      None
# 3            False                                       None      None
# 4            False                                       None      None
# 5            False                                       None      None
# 6            False                                       None      None
# 7            False                                       None      None
# 8            False                                       None      None
# 9            False                                       None      None
# 10           False                                       None      None
# 11           False                                       None      None
# 12           False                                       None      None
# 13           False                                       None      None
# 14           False                                       None      None
# 15           False                                       None      None
# 16           False                                       None      None
# 17           False                                       None      None
# 18           False                                       None      None
# 19           False                                       None      None
# 20           False                                       None      None
# 21           False                                       None      None
# 22           False                                       None      None
# 23           False                                       None      None
# 24           False                                       None      None

# %% [markdown]
# # Orders
#
# http://interactivebrokers.github.io/tws-api/orders.html
#
# http://interactivebrokers.github.io/tws-api/basic_orders.html

# %%
util.startLoop()

# %% [markdown]
# ## Market Order

# %%
contract = Forex('USDJPY')
ib.qualifyContracts(contract)

order = MarketOrder('BUY', 100000)

# %%
trade = ib.placeOrder(contract, order)

trade
# Out:
# Trade(contract=Forex('USDJPY', conId=15016059, exchange='IDEALPRO', localSymbol='USD.JPY', tradingClass='USD.JPY'), order=MarketOrder(orderId=15, action='BUY', totalQuantity=100000), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2018, 4, 16, 15, 31, 49, 233095, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])

# %%
ib.sleep(1)
trade.log
# Out:
# [TradeLogEntry(time=datetime.datetime(2018, 4, 16, 15, 31, 49, 233095, tzinfo=datetime.timezone.utc), status='PendingSubmit', message=''),
#  TradeLogEntry(time=datetime.datetime(2018, 4, 16, 15, 31, 49, 683225, tzinfo=datetime.timezone.utc), status='Submitted', message=''),
#  TradeLogEntry(time=datetime.datetime(2018, 4, 16, 15, 31, 49, 999508, tzinfo=datetime.timezone.utc), status='Submitted', message='Fill 100000.0@107.244'),
#  TradeLogEntry(time=datetime.datetime(2018, 4, 16, 15, 31, 49, 999508, tzinfo=datetime.timezone.utc), status='Filled', message='')]

# %% [markdown]
# ## Limit Order

# %%
limitOd = LimitOrder('BUY', 100000, 100)
limitTrade = ib.placeOrder(contract, limitOd)

limitTrade
# Out:
# Trade(contract=Forex('USDJPY', conId=15016059, exchange='IDEALPRO', localSymbol='USD.JPY', tradingClass='USD.JPY'), order=LimitOrder(orderId=16, action='BUY', totalQuantity=100000, lmtPrice=100), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2018, 4, 16, 15, 31, 50, 634734, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])

# %%
ib.sleep(1)
assert limitTrade.orderStatus.status == 'Submitted'

# %%
assert limitTrade in ib.openTrades()

# %%
ib.openOrders()
# Out:
# [LimitOrder(orderId=16, action='BUY', totalQuantity=100000, lmtPrice=100)]

# %% [markdown]
# We can modify the limit price

# %%
ib.cancelOrder(limitOd)
# Out:
# Trade(contract=Forex('USDJPY', conId=15016059, exchange='IDEALPRO', localSymbol='USD.JPY', tradingClass='USD.JPY'), order=LimitOrder(orderId=16, action='BUY', totalQuantity=100000, lmtPrice=100), orderStatus=OrderStatus(status='Submitted', remaining=100000.0, permId=273977873, clientId=32, mktCapPrice=None), fills=[], log=[TradeLogEntry(time=datetime.datetime(2018, 4, 16, 15, 31, 50, 634734, tzinfo=datetime.timezone.utc), status='PendingSubmit', message=''), TradeLogEntry(time=datetime.datetime(2018, 4, 16, 15, 31, 50, 929823, tzinfo=datetime.timezone.utc), status='Submitted', message=''), TradeLogEntry(time=datetime.datetime(2018, 4, 16, 15, 31, 52, 5170, tzinfo=datetime.timezone.utc), status='PendingCancel', message='')])

# %%
limitTrade.log
# Out:
# [TradeLogEntry(time=datetime.datetime(2018, 4, 16, 15, 31, 50, 634734, tzinfo=datetime.timezone.utc), status='PendingSubmit', message=''),
#  TradeLogEntry(time=datetime.datetime(2018, 4, 16, 15, 31, 50, 929823, tzinfo=datetime.timezone.utc), status='Submitted', message=''),
#  TradeLogEntry(time=datetime.datetime(2018, 4, 16, 15, 31, 52, 5170, tzinfo=datetime.timezone.utc), status='PendingCancel', message='')]

# %% [markdown]
# ***

# %% [markdown]
# # Historical Data
# ## Bar Data
# http://interactivebrokers.github.io/tws-api/historical_bars.html

# %%
contract = Stock('IBM', 'SMART', 'USD')
#contract = Forex('AUDUSD')
#ib.reqHeadTimeStamp(contract, whatToShow='TRADES', useRTH=True)

# %%
bars = ib.reqHistoricalData(contract,
                            endDateTime='',
                            durationStr = '300 D',
                            barSizeSetting = '1 day',
                            whatToShow = 'TRADES',
                            useRTH = True,
                            formatDate = 1)

# %%
bars[0]
# Out:
# BarData(date=datetime.date(2017, 2, 6), open=175.41, high=175.98, low=174.38, close=175.86, volume=19264, barCount=13164, average=175.366)

# %%
df = util.df(bars)

df.head()
# Out:
#          date    open    high     low   close  volume  barCount   average
# 0  2017-02-06  175.41  175.98  174.38  175.86   19264     13164  175.3660
# 1  2017-02-07  176.09  178.62  175.90  178.46   29734     20880  177.9100
# 2  2017-02-08  177.50  177.50  175.88  176.17   20839     14303  176.4360
# 3  2017-02-09  176.17  177.80  175.91  177.21   19361     13072  177.0500
# 4  2017-02-10  177.37  178.88  176.76  178.68   17086     11208  178.0935

# %%
df.tail()
# Out:
#            date    open    high     low   close  volume  barCount  average
# 295  2018-04-10  155.03  156.61  154.75  155.39   27713     19615  155.599
# 296  2018-04-11  154.37  155.78  153.88  155.36   23540     17282  154.952
# 297  2018-04-12  156.75  158.98  156.67  158.07   39479     29229  158.145
# 298  2018-04-13  158.67  159.22  155.91  156.71   27817     21709  157.196
# 299  2018-04-16  157.91  159.02  157.76  158.74    5459      2293  158.376

# %%
df.close.plot()

# %%
util.barplot(bars[-50:], title=contract.symbol);

# %% [markdown]
# # Tick Data
#
# http://interactivebrokers.github.io/tws-api/top_data.html

# %%
contract = Forex('AUDUSD')

ib.reqMktData(contract, '', False, False)
# Out:
# Ticker(contract=Forex('AUDUSD', exchange='IDEALPRO'), ticks=[], tickByTicks=[], domBids=[], domAsks=[], domTicks=[])

# %%
ticker = ib.ticker(contract)
ib.sleep(2)

ticker
# Out:
# Ticker(contract=Forex('AUDUSD', exchange='IDEALPRO'), time=datetime.datetime(2018, 5, 15, 3, 12, 46, 252972, tzinfo=datetime.timezone.utc), bid=0.75319, bidSize=1000000, ask=0.75323, askSize=3500000, high=0.7538, low=0.7522, close=0.75265, ticks=[TickData(time=datetime.datetime(2018, 5, 15, 3, 12, 46, 252972, tzinfo=datetime.timezone.utc), tickType=6, price=0.7538, size=0), TickData(time=datetime.datetime(2018, 5, 15, 3, 12, 46, 252972, tzinfo=datetime.timezone.utc), tickType=7, price=0.7522, size=0), TickData(time=datetime.datetime(2018, 5, 15, 3, 12, 46, 252972, tzinfo=datetime.timezone.utc), tickType=9, price=0.75265, size=0), TickData(time=datetime.datetime(2018, 5, 15, 3, 12, 46, 252972, tzinfo=datetime.timezone.utc), tickType=1, price=0.75319, size=1000000), TickData(time=datetime.datetime(2018, 5, 15, 3, 12, 46, 252972, tzinfo=datetime.timezone.utc), tickType=2, price=0.75323, size=3500000), TickData(time=datetime.datetime(2018, 5, 15, 3, 12, 46, 252972, tzinfo=datetime.timezone.utc), tickType=0, price=0.75319, size=1000000), TickData(time=datetime.datetime(2018, 5, 15, 3, 12, 46, 252972, tzinfo=datetime.timezone.utc), tickType=3, price=0.75323, size=3500000)], tickByTicks=[], domBids=[], domAsks=[], domTicks=[])

# %%
ticker.marketPrice()
# Out:
# 0.7532099999999999

# %%
ib.cancelMktData(contract)

# %%
util
# Out:
# <module 'ib_insync.util' from '/usr/local/anaconda3/lib/python3.6/site-packages/ib_insync/util.py'>

# %% [markdown]
# ***
